# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mahdy\OneDrive\Desktop\global_tech_salary.txt", sep=",")
df
# Out:
#       work_year experience_level employment_type  \
# 0          2023               MI              FT
# 1          2023               MI              FT
# 2          2024               MI              FT
# 3          2024               SE              FT
# 4          2023               MI              FT
# ...         ...              ...             ...
# 4995       2023               SE              FT
# 4996       2022               SE              FT
# 4997       2024               SE              FT
# 4998       2022               EN              FT
# 4999       2023               SE              FT
#
#                                      job_title  salary salary_currency  \
# 0                                 Data Analyst  165000             USD
# 1                                 Data Analyst   70000             USD
# 2                    Machine Learning Engineer   85000             EUR
# 3                               Data Scientist   92700             USD
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               MI              FT               Data Analyst
# 1       2023               MI              FT               Data Analyst
# 2       2024               MI              FT  Machine Learning Engineer
# 3       2024               SE              FT             Data Scientist
# 4       2023               MI              FT          Research Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  165000             USD         165000                 AU             0
# 1   70000             USD          70000                 US           100
# 2   85000             EUR          94444                 IE           100
# 3   92700             USD          92700                 US             0
# 4  150000             USD         150000                 US             0
#
#   company_location company_size
# 0               AU            M
# ...

# %%
df.sample(5)
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 2098       2023               SE              FT   Data Engineer  145000
# 2395       2024               MI              FT  Data Developer   95000
# 4882       2024               SE              FT   Data Engineer  103000
# 4722       2023               MI              FT   Data Engineer  102000
# 782        2023               SE              FT   Data Engineer   94000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 2098             USD         145000                 US             0
# 2395             USD          95000                 US             0
# 4882             USD         103000                 US             0
# 4722             USD         102000                 US             0
# 782              USD          94000                 US             0
#
#      company_location company_size
# 2098               US            M
# 2395               US            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           5000 non-null   int64
#  1   experience_level    5000 non-null   object
#  2   employment_type     5000 non-null   object
#  3   job_title           5000 non-null   object
#  4   salary              5000 non-null   int64
#  5   salary_currency     5000 non-null   object
#  6   salary_in_usd       5000 non-null   int64
#  7   employee_residence  5000 non-null   object
#  8   remote_ratio        5000 non-null   int64
#  9   company_location    5000 non-null   object
#  10  company_size        5000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 429.8+ KB

# %%
df["experience_level"] = df["experience_level"].replace({
    "EN":"Entry Level",
    "MI":"Mid Level",
    "SE":"Senior Level",
    "EX":"Executive Level"
})

# %%
df["experience_level"].value_counts()
# Out:
# experience_level
# Senior Level       3248
# Mid Level          1215
# Entry Level         375
# Executive Level     162
# Name: count, dtype: int64

# %%
df["employment_type"] = df["employment_type"].replace({
    "FT":"Full Time",
    "PT":"Part Time",
    "CT":"Contract",
    "FL":"Full Time"
})

# %%
df["employment_type"].value_counts()
# Out:
# employment_type
# Full Time    4981
# Contract       10
# Part Time       9
# Name: count, dtype: int64

# %%
df["company_size"]= df["company_size"].replace({
    "S":"Small",
    "M":"Medium",
    "L":"Large"

})

# %%
df["company_size"].value_counts()
# Out:
# company_size
# Medium    4603
# Large      335
# Small       62
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           5000 non-null   int64
#  1   experience_level    5000 non-null   object
#  2   employment_type     5000 non-null   object
#  3   job_title           5000 non-null   object
#  4   salary              5000 non-null   int64
#  5   salary_currency     5000 non-null   object
#  6   salary_in_usd       5000 non-null   int64
#  7   employee_residence  5000 non-null   object
#  8   remote_ratio        5000 non-null   int64
#  9   company_location    5000 non-null   object
#  10  company_size        5000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 429.8+ KB

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023        Mid Level       Full Time               Data Analyst
# 1       2023        Mid Level       Full Time               Data Analyst
# 2       2024        Mid Level       Full Time  Machine Learning Engineer
# 3       2024     Senior Level       Full Time             Data Scientist
# 4       2023        Mid Level       Full Time          Research Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  165000             USD         165000                 AU             0
# 1   70000             USD          70000                 US           100
# 2   85000             EUR          94444                 IE           100
# 3   92700             USD          92700                 US             0
# 4  150000             USD         150000                 US             0
#
#   company_location company_size
# 0               AU       Medium
# ...

# %%
df["employee_residence"].value_counts()
# Out:
# employee_residence
# US    4388
# GB     198
# CA     116
# ES      52
# DE      34
# FR      21
# IN      21
# AU      14
# PT      13
# BR      10
# NL       9
# IE       7
# IT       6
# PL       6
# ZA       5
# LT       5
# CO       5
# MX       5
# EG       5
# AR       5
# VN       5
# NG       5
# GR       4
# SI       4
# BE       4
# PH       4
# TR       4
# AE       3
# EE       3
# JP       3
# UA       3
# CF       2
# DK       2
# TH       2
# LV       2
# SG       2
# MT       2
# PK       2
# RO       2
# GH       2
# NZ       1
# FI       1
# MD       1
# KR       1
# AT       1
# EC       1
# HK       1
# RU       1
# SE       1
# CY       1
# CH       1
# RS       1
# HN       1
# AM       1
# IQ       1
# Name: count, dtype: int64

# %%
df["employee_residence"]=df["employee_residence"].replace({
    "US": "United States",
    "CY": "Cyprus",
    "UA": "Ukraine",
    "RS": "Serbia",
    "HN": "Honduras",
    "AM": "Armenia",
    "IQ": "Iraq",
    "EC": "Ecuador",
    "HK": "Hong Kong",
    "MD": "Moldova",
    "GH": "Ghana",
    "PK": "Pakistan",
    "MT": "Malta",
    "LV": "Latvia",
    "CF": "Central African Republic",
    "EE": "Estonia",
    "SI": "Slovenia",
    "LT": "Lithuania",
    "GB": "United Kingdom",
    "UK": "United Kingdom",
    "DE": "Germany",
    "FR": "France",
    "ES": "Spain",
    "IT": "Italy",
    "CA": "Canada",
    "AU": "Australia",
    "IN": "India",
    "CN": "China",
    "JP": "Japan",
    "BR": "Brazil",
    "MX": "Mexico",
    "RU": "Russia",
    "KR": "South Korea",
    "NL": "Netherlands",
    "BE": "Belgium",
    "SE": "Sweden",
    "NO": "Norway",
    "DK": "Denmark",
    "FI": "Finland",
    "CH": "Switzerland",
    "AT": "Austria",
    "PL": "Poland",
    "PT": "Portugal",
    "GR": "Greece",
    "IE": "Ireland",
    "CZ": "Czech Republic",
    "HU": "Hungary",
    "RO": "Romania",
    "BG": "Bulgaria",
    "TR": "Turkey",
    "SA": "Saudi Arabia",
    "AE": "United Arab Emirates",
    "EG": "Egypt",
    "ZA": "South Africa",
    "NG": "Nigeria",
    "KE": "Kenya",
    "MA": "Morocco",
    "TN": "Tunisia",
    "AR": "Argentina",
    "CL": "Chile",
    "CO": "Colombia",
    "PE": "Peru",
    "ID": "Indonesia",
    "MY": "Malaysia",
    "SG": "Singapore",
    "TH": "Thailand",
    "VN": "Vietnam",
    "PH": "Philippines",
    "NZ": "New Zealand" 
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           5000 non-null   int64
#  1   experience_level    5000 non-null   object
#  2   employment_type     5000 non-null   object
#  3   job_title           5000 non-null   object
#  4   salary              5000 non-null   int64
#  5   salary_currency     5000 non-null   object
#  6   salary_in_usd       5000 non-null   int64
#  7   employee_residence  5000 non-null   object
#  8   remote_ratio        5000 non-null   int64
#  9   company_location    5000 non-null   object
#  10  company_size        5000 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 429.8+ KB

# %%
df["company_location"]=df["company_location"].replace({
    "US": "United States",
    "CY": "Cyprus",
    "UA": "Ukraine",
    "RS": "Serbia",
    "HN": "Honduras",
    "AM": "Armenia",
    "IQ": "Iraq",
    "EC": "Ecuador",
    "HK": "Hong Kong",
    "MD": "Moldova",
    "GH": "Ghana",
    "PK": "Pakistan",
    "MT": "Malta",
    "LV": "Latvia",
    "CF": "Central African Republic",
    "EE": "Estonia",
    "SI": "Slovenia",
    "LT": "Lithuania",
    "GB": "United Kingdom",
    "UK": "United Kingdom",
    "DE": "Germany",
    "FR": "France",
    "ES": "Spain",
    "IT": "Italy",
    "CA": "Canada",
    "AU": "Australia",
    "IN": "India",
    "CN": "China",
    "JP": "Japan",
    "BR": "Brazil",
    "MX": "Mexico",
    "RU": "Russia",
    "KR": "South Korea",
    "NL": "Netherlands",
    "BE": "Belgium",
    "SE": "Sweden",
    "NO": "Norway",
    "DK": "Denmark",
    "FI": "Finland",
    "CH": "Switzerland",
    "AT": "Austria",
    "PL": "Poland",
    "PT": "Portugal",
    "GR": "Greece",
    "IE": "Ireland",
    "CZ": "Czech Republic",
    "HU": "Hungary",
    "RO": "Romania",
    "BG": "Bulgaria",
    "TR": "Turkey",
    "SA": "Saudi Arabia",
    "AE": "United Arab Emirates",
    "EG": "Egypt",
    "ZA": "South Africa",
    "NG": "Nigeria",
    "KE": "Kenya",
    "MA": "Morocco",
    "TN": "Tunisia",
    "AR": "Argentina",
    "CL": "Chile",
    "CO": "Colombia",
    "PE": "Peru",
    "ID": "Indonesia",
    "MY": "Malaysia",
    "SG": "Singapore",
    "TH": "Thailand",
    "VN": "Vietnam",
    "LU": "Luxembourg",
    "AS": "American Samoa",
    "PH": "Philippines",
    "NZ": "New Zealand" 
})

# %%
df["company_location"].value_counts()
# Out:
# company_location
# United States               4402
# United Kingdom               202
# Canada                       115
# Spain                         52
# Germany                       34
# France                        20
# Australia                     16
# India                         16
# Portugal                      12
# Netherlands                   11
# Brazil                         9
# Ireland                        7
# Mexico                         6
# Poland                         6
# Colombia                       5
# Lithuania                      5
# South Africa                   5
# Italy                          5
# Egypt                          4
# Nigeria                        4
# Slovenia                       4
# Estonia                        4
# United Arab Emirates           3
# Argentina                      3
# Vietnam                        3
# Turkey                         3
# Malta                          2
# Thailand                       2
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023        Mid Level       Full Time               Data Analyst
# 1       2023        Mid Level       Full Time               Data Analyst
# 2       2024        Mid Level       Full Time  Machine Learning Engineer
# 3       2024     Senior Level       Full Time             Data Scientist
# 4       2023        Mid Level       Full Time          Research Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  165000             USD         165000          Australia             0
# 1   70000             USD          70000      United States           100
# 2   85000             EUR          94444            Ireland           100
# 3   92700             USD          92700      United States             0
# 4  150000             USD         150000      United States             0
#
#   company_location company_size
# 0        Australia       Medium
# ...

# %%
df.to_csv("Salary.csv",sep=",", index=False)
